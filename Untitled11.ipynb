# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawanss/football/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/drive/MyDrive/miniproject_football/footballmatch_PR.csv")

# %%
data.columns
# Out:
# Index(['Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTR', 'HS',
#        'AS', 'HST', 'AST', 'HC', 'AC', 'B365H', 'B365D', 'B365A', 'AvgH',
#        'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5',
#        'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'AvgAHH', 'AvgAHA'],
#       dtype='object')

# %%
x = data[["HomeTeam","AwayTeam","FTHG","FTAG","HS","AS","HST","AST",'B365H', 'B365D', 'B365A','B365>2.5', 'B365<2.5','FTR']]

# %%
#rename
x.rename(columns={'FTHG': 'homegoals', 'FTAG': 'awaygoals','FTR':'winner'}, inplace=True)
# Out:
# <ipython-input-26-1ba123050cb1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.rename(columns={'FTHG': 'homegoals', 'FTAG': 'awaygoals','FTR':'winner'}, inplace=True)

# %%
x["sumgolas"] = x["homegoals"] + x["awaygoals"]
# Out:
# <ipython-input-29-5113644ba2ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["sumgolas"] = x["homegoals"] + x["awaygoals"]

# %%
x
# Out:
#              HomeTeam       AwayTeam  homegoals  awaygoals  HS  AS  HST  AST  \
# 0             Burnley       Man City          0          3   6  17    1    8
# 1             Arsenal  Nott'm Forest          2          1  15   6    7    2
# 2         Bournemouth       West Ham          1          1  14  16    5    3
# 3            Brighton          Luton          4          1  27   9   12    3
# 4             Everton         Fulham          0          1  19   9    9    2
# ..                ...            ...        ...        ...  ..  ..  ...  ...
# 351  Sheffield United  Nott'm Forest          1          3  17  15    5    4
# 352          Man City         Wolves          5          1  20   2   12    1
# 353          Brighton    Aston Villa          1          0  15   2    8    1
# 354           Chelsea       West Ham          5          0  25  13   14    2
# 355         Liverpool      Tottenham          4          2  25  11   13    6
#
#      B365H  B365D  B365A  B365>2.5  B365<2.5 winner  sumgolas
# 0     8.00   5.50   1.33      1.67      2.20      A         3
# 1     1.18   7.00  15.00      1.44      2.75      H         3
# 2     2.70   3.40   2.55      1.90      2.00      D         2
# 3     1.33   5.50   9.00      1.62      2.30      H         5
# 4     2.20   3.40   3.30      2.01      1.89      A         1
# ..     ...    ...    ...       ...       ...    ...       ...
# 351   4.75   4.20   1.65      1.57      2.38      A         4
# 352   1.08  12.00  21.00      1.30      3.50      H         6
# 353   2.75   3.75   2.45      1.50      2.63      H         1
# 354   1.65   4.50   4.50      1.40      3.00      H         5
# 355   1.50   5.75   5.00      1.25      4.00      H         6
#
# [356 rows x 15 columns]

# %%
x['hilow2.5'] = np.where(x['sumgolas']>2, 'HI', 'LOW')
# Out:
# <ipython-input-39-6ac572feda79>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['hilow2.5'] = np.where(x['sumgolas']>2, 'HI', 'LOW')

# %%
x
# Out:
#              HomeTeam       AwayTeam  homegoals  awaygoals  HS  AS  HST  AST  \
# 0             Burnley       Man City          0          3   6  17    1    8
# 1             Arsenal  Nott'm Forest          2          1  15   6    7    2
# 2         Bournemouth       West Ham          1          1  14  16    5    3
# 3            Brighton          Luton          4          1  27   9   12    3
# 4             Everton         Fulham          0          1  19   9    9    2
# ..                ...            ...        ...        ...  ..  ..  ...  ...
# 351  Sheffield United  Nott'm Forest          1          3  17  15    5    4
# 352          Man City         Wolves          5          1  20   2   12    1
# 353          Brighton    Aston Villa          1          0  15   2    8    1
# 354           Chelsea       West Ham          5          0  25  13   14    2
# 355         Liverpool      Tottenham          4          2  25  11   13    6
#
#      B365H  B365D  B365A  B365>2.5  B365<2.5 winner  sumgolas hilow2.5
# 0     8.00   5.50   1.33      1.67      2.20      A         3       HI
# 1     1.18   7.00  15.00      1.44      2.75      H         3       HI
# 2     2.70   3.40   2.55      1.90      2.00      D         2      LOW
# 3     1.33   5.50   9.00      1.62      2.30      H         5       HI
# 4     2.20   3.40   3.30      2.01      1.89      A         1      LOW
# ..     ...    ...    ...       ...       ...    ...       ...      ...
# 351   4.75   4.20   1.65      1.57      2.38      A         4       HI
# 352   1.08  12.00  21.00      1.30      3.50      H         6       HI
# 353   2.75   3.75   2.45      1.50      2.63      H         1      LOW
# 354   1.65   4.50   4.50      1.40      3.00      H         5       HI
# 355   1.50   5.75   5.00      1.25      4.00      H         6       HI
#
# [356 rows x 16 columns]

# %%
print(x["hilow2.5"].value_counts())
# Out:
# hilow2.5
# HI     228
# LOW    128
# Name: count, dtype: int64

# %%
x[(x["hilow2.5"] == "HI")]['B365>2.5'].sum()
# Out:
# 372.84000000000003
